# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from IPython.display import Audio

# %%
sample = np.frombuffer(open("git/opl2/samples/adsr4f0f.bin").read()[10:], np.uint16) >> 3
print sample[-1]
# Out:
# 5098

# %%
e = ((sample >> 10) & 7) - 1  # should e=0 be considered a shift of 8?
s = ((sample & 1023).astype(np.int32) - 512)*2 + 1 << e
plt.plot(s[256::512], '-x')
plt.plot(s[260::512], '-x')
print s[256::512]
# Out:
# [   1    1    1    5   13   29   59  109  189  303  469  677  937 1242 1574
#  1958 2380 2828 3292 3748 4184 4552 4968 5304 5656 6040 6296 6584 6872 7176
#  7336 7496 7656 7832 7992 8168 8168 8168 8168 8168 8168 8168 8168 8168 8168
#  8168 8168 8168 8168 8168 8168 8168 8168 8168 8168 8168 8168 8168 8168]

# %%
Audio(s, rate=48000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(s)

# %%
print s[256::512]
# Out:
# [   1    1    5   13   29   59  109  189  303  469  677  937 1242 1574 1958
#  2380 2828 3292 3748 4184 4552 4968 5304 5656 6040 6296 6584 6872 7176 7336
#  7496 7656 7832 7992 8168 7992 7832 7656 7496 7336 7176 7016 6872 6728 6584
#  6440 6296 6168 6040 5912 5784 5656 5528 5416 5304 5192 5080 4968 4856]

# %%
hex(0x02 << 14)
# Out:
# '0x8000'
